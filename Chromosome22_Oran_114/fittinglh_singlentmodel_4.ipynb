# %%
import argparse
import cogent3
from cogent3 import get_app
from cogent3 import load_aligned_seqs
import paths

# %%
region = "cds"
relative_folder_in = region + "/chrm22"
folder_in = paths.DATA_HUMCHIMPORANGOR114 + relative_folder_in

file_in = folder_in + "/singlent_filtered.fa"

alns = load_aligned_seqs(file_in, moltype="dna")
alns
# Out:
# 3 x 536267 dna alignment: Human[ATGAGTTCGC...], Chimpanzee[ATGAGTTCGC...], Orangutan[ATGAGTTCGC...]
