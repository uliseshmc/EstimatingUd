# %%
import matplotlib.pyplot as plt

# %%
divergence_data = {
    "cds1": 1.0000030489883934e-06,
    "cds2": 9.99999071551414e-07,
    "cds3": 9.999993105673513e-07,
    "ffold": 9.999974725589267e-07,

    "intron": 0.00580774563048338,
    "intron_AR": 0.0058256502959231436,

    "IG": 0.007351086704508361,
    "IG_AR": 0.007596074855821766
}

divergence_data_cds = {
    "cds1": 1.0000030489883934e-06,
    "cds2": 9.99999071551414e-07,
    "cds3": 9.999993105673513e-07,
    "ffold": 9.999974725589267e-07
}

divergence_data_notcds = {
    "intron": 0.00580774563048338,
    "intron_AR": 0.0058256502959231436,

    "IG": 0.007351086704508361,
    "IG_AR": 0.007596074855821766
}

divergence_data_allcds = {
    "cds1": 1.0000030489883934e-06,
    "cds2": 9.99999071551414e-07,
    "cds3": 9.999993105673513e-07,
    "ffold": 9.999974725589267e-07,
    
    "cds1_nocdaln": 1.0000071939905418e-06,
    "cds2_nocdaln": 9.99999018670744e-07,
    "cds3_nocdaln": 9.999975103250148e-07,
}

plt.figure()
plt.bar(divergence_data_cds.keys(), divergence_data_cds.values())
plt.ylabel("Estimated number of substitutions")
plt.title("Human cds")
plt.ylim(0.000000075,0.000002)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure()
plt.bar(divergence_data_allcds.keys(), divergence_data_allcds.values())
plt.yscale("log")  # log scale so small values are visible
plt.ylabel("Estimated number of substitutions")
plt.title("Human not aligned")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure()
plt.bar(divergence_data_notcds.keys(), divergence_data_notcds.values())
plt.ylabel("Estimated number of substitutions")
plt.title("Human noncds")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
divergence_data_humans_ntaligned = {
    "cds1": 1.0000030489883934e-06,
    "cds2": 9.99999071551414e-07,
    "cds3": 9.999993105673513e-07,
    "ffold": 9.999974725589267e-07,

    "intron_ntaligned": 0.009092615382385733
}

plt.figure()
plt.bar(divergence_data_humans_ntaligned.keys(), divergence_data_humans_ntaligned.values())
plt.yscale("log")  # log scale so small values are visible
plt.ylabel("Divergence")
plt.title("Human intron_ntaligned")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
divergence_data_chimps = {
    "cds1": 0.00014730596435591644,
    "cds2": 0.00016309196938155157,
    "cds3": 0.00022097800934762883,
    "ffold": 0.00012508920151561956,

    "intron": 0.006067054093488167,
    "intron_AR": 0.011914876774019104,

    "IG": 0.007611661733108486,
    "IG_AR": 0.00838722041640563
}

divergence_data_chimps_all = {
    "cds1": 0.00014730596435591644,
    "cds2": 0.00016309196938155157,
    "cds3": 0.00022097800934762883,
    "ffold": 0.00012508920151561956,

    "cdsall_nocdaln": 1.7791928039760448e-06,
    "cds1_nocdaln": 1.0000063504046007e-06,
    "cds2_nocdaln": 5.337659820461585e-06,
    "cds3_nocdaln": 9.99997510540699e-07,

    "intron": 0.006067054093488167,
    "intron_AR": 0.011914876774019104,

    "IG": 0.007611661733108486,
    "IG_AR": 0.00838722041640563
}

# %%
plt.figure(figsize=(8,5))
plt.bar(divergence_data_chimps_all.keys(), divergence_data_chimps_all.values())
plt.yscale("log")  # log scale so small values are visible

plt.ylabel("Divergence")
plt.title("Chimps")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
