# %%
import cogent3
from cogent3 import get_app
from cogent3 import load_aligned_seqs
import matplotlib.pyplot as plt
import libs
import paths

# %%
#Define apps
omit_degs_noncds = get_app("omit_degenerates", moltype="dna")
rename_noncds = libs.renamer_noncds_aligned()
sm_GN = get_app("model", "GN", time_het="max", optimise_motif_probs=True, show_progress=True)

# %% [markdown]
# # Introns

# %%
folder_in = paths.DATA_APES114 + 'introns/'

sequence = 'ENSG00000100373.fa'
aln1 = load_aligned_seqs(filename = folder_in + sequence, format_name="fasta", moltype='dna')
aln1 = rename_noncds(aln1)
aln1 = omit_degs_noncds(aln1)

#result_introns1 = sm_GN(aln1)
#lengthstree_introns1 = result_introns1.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_introns1.lf) + "\n")
#print("Distances: " + str(lengthstree_introns1))

# %%
aln1
# Out:
# 3 x 3343 dna alignment: Human[AGGTCTGGTG...], Chimpanzee[AGGTCTGGTG...], Gorilla[AGGTCTGGTG...]

# %%
folder_in = paths.DATA_APES114 + 'introns/nt_aligned/'

aln_ntaligned1 = load_aligned_seqs(filename = folder_in + sequence, format="fasta", moltype='dna')
#aln_ntaligned1 = omit_degs_noncds(aln_ntaligned1)
#aln_ntaligned1

#result_introns_ntaligned1 = sm_GN(aln_ntaligned1)
#lengthstree_introns_ntaligned1 = result_introns_ntaligned1.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_introns_ntaligned.lf) + "\n")
#print("Distances: " + str(lengthstree_introns_ntaligned1))
# Out:
# /home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/cogent3/util/warning.py:134: DeprecationWarning: argument format which will be removed in version 2025.9, use format_name instead
# reason='no longer has an effect'
#   deprecated(

# %%
aln_ntaligned1
# Out:
# 3 x 5505 dna alignment: Human[AGGTCTGGTG...], Chimpanzee[AGGTCTGGTG...], Gorilla[AGGTCTGGTG...]

# %%
varpos_ensemblaligned = sorted(aln1.variable_positions())
varpos_ntaligned = sorted(aln_ntaligned1.variable_positions())

print(varpos_ensemblaligned[30:80])
print(varpos_ntaligned[30:80])
# Out:
# [974, 1047, 1051, 1053, 1057, 1074, 1148, 1218, 1226, 1250, 1306, 1318, 1354, 1431, 1463, 1552, 1588, 1614, 1616, 1620, 1649, 1678, 1739, 1746, 1888, 1936, 2012, 2016, 2037, 2065, 2095, 2127, 2173, 2190, 2221, 2236, 2251, 2262, 2355, 2362, 2439, 2451, 2460, 2483, 2487, 2603, 2642, 2662, 2690, 2728]
# [974, 1047, 1051, 1053, 1057, 1074, 1148, 1218, 1226, 1250, 1306, 1318, 1354, 1431, 1462, 1540, 1543, 1544, 1545, 1547, 1548, 1550, 1558, 1559, 1560, 1561, 1565, 1578, 1614, 1640, 1642, 1646, 1675, 1704, 1765, 1772, 1914, 1962, 2038, 2042, 2063, 2091, 2121, 2153, 2199, 2216, 2247, 2262, 2277, 2288]

# %%
aln1[1530:1590]
# Out:
# 3 x 60 dna alignment: Human[TCAACTTCTG...], Chimpanzee[TCAACTTCTG...], Gorilla[TCAACTTCTG...]

# %%
aln_ntaligned1[1529:1590]
# Out:
# 3 x 61 dna alignment: Human[TCAACTTCTG...], Chimpanzee[TCAACTTCTG...], Gorilla[TCAACTTCTG...]

# %%
dp_allpos = aln1.dotplot(name1="Human", name2="Chimpanzee", title="intron")
dp_allpos.show()
dp_allpos = aln_ntaligned1.dotplot(name1="Human", name2="Chimpanzee", title="intron nt aligned")
dp_allpos.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
folder_in = paths.DATA_APES114 + 'introns/'

sequence = 'ENSG00000100075.fa'
aln2 = load_aligned_seqs(filename = folder_in + sequence, format_name="fasta", moltype='dna')
aln2 = rename_noncds(aln2)
aln2 = omit_degs_noncds(aln2)

result_introns2 = sm_GN(aln2)
lengthstree_introns2 = result_introns2.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_introns2.lf) + "\n")
print("Distances: " + str(lengthstree_introns2))
# Out:
#    0%|          |00:00<?
#    0%|          |00:00<?
# Distances: {'Human': np.float64(0.00574467487796801), 'Chimpanzee': np.float64(0.004703322228026665), 'Gorilla': np.float64(0.011039181275424794)}

# %%
folder_in = paths.DATA_APES114 + 'introns/nt_aligned/'

aln_ntaligned2 = load_aligned_seqs(filename = folder_in + sequence, format_name="fasta", moltype='dna')
aln_ntaligned2 = omit_degs_noncds(aln_ntaligned2)
aln_ntaligned2

result_introns_ntaligned2 = sm_GN(aln_ntaligned2)
lengthstree_introns_ntaligned2 = result_introns_ntaligned2.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_introns_ntaligned2.lf) + "\n")
print("Distances: " + str(lengthstree_introns_ntaligned2))
# Out:
#    0%|          |00:00<?
#    0%|          |00:00<?
# Distances: {'Human': np.float64(0.006265285851335834), 'Chimpanzee': np.float64(0.005210286339014714), 'Gorilla': np.float64(0.011027943892328874)}

# %%
dp_allpos = aln2.dotplot(name1="Human", name2="Chimpanzee", title="intron")
dp_allpos.show()
dp_allpos = aln_ntaligned2.dotplot(name1="Human", name2="Chimpanzee", title="intron nt aligned")
dp_allpos.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Introns AR

# %%
folder_in = paths.DATA_APES114 + 'intronsAR/'

sequence = 'ENSG00000100147.fa'
aln_intronsAR1 = load_aligned_seqs(filename = folder_in + sequence, format_name="fasta", moltype='dna')
aln_intronsAR1 = rename_noncds(aln_intronsAR1)
aln_intronsAR1 = omit_degs_noncds(aln_intronsAR1)

result_intronsAR1 = sm_GN(aln_intronsAR1)
lengthstree_intronsAR1 = result_intronsAR1.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_intronsAR1.lf) + "\n")
print("Distances: " + str(lengthstree_intronsAR1))
# Out:
#    0%|          |00:00<?
#    0%|          |00:00<?
# Distances: {'Human': np.float64(0.005033443116454307), 'Chimpanzee': np.float64(0.005090877804831053), 'Gorilla': np.float64(0.012644615173461606)}

# %%
folder_in = paths.DATA_APES114 + 'intronsAR/nt_aligned/'

aln_intronsAR_ntaligned1 = load_aligned_seqs(filename = folder_in + sequence, format_name="fasta", moltype='dna')
aln_intronsAR_ntaligned1 = rename_noncds(aln_intronsAR_ntaligned1)
aln_intronsAR_ntaligned1 = omit_degs_noncds(aln_intronsAR_ntaligned1)

result_intronsAR_ntaligned1 = sm_GN(aln_intronsAR_ntaligned1)
lengthstree_intronsAR_ntaligned1 = result_intronsAR_ntaligned1.lf.get_lengths_as_ens()
#print("Model results : \n" + str(result_intronsAR_ntaligned1.lf) + "\n")
print("Distances: " + str(lengthstree_intronsAR_ntaligned1))
# Out:
#    0%|          |00:00<?
#    0%|          |00:00<?
# Distances: {'Human': np.float64(0.0055455960549567395), 'Chimpanzee': np.float64(0.005401160659614027), 'Gorilla': np.float64(0.018053599755304413)}

# %%
dp_allpos = aln_intronsAR1.dotplot(name1="Human", name2="Chimpanzee", title="intron")
dp_allpos.show()
dp_allpos = aln_intronsAR_ntaligned1.dotplot(name1="Human", name2="Chimpanzee", title="intron nt aligned")
dp_allpos.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
