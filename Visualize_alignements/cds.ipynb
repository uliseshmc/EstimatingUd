# %%
import cogent3
from cogent3 import get_app
from cogent3 import load_aligned_seqs
from cogent3 import load_unaligned_seqs
from cogent3 import make_seq
from cogent3 import make_aligned_seqs
from cogent3 import make_unaligned_seqs
from cogent3.align.progressive import tree_align
import paths

# %%
folder_in = paths.DATA_APES114 + 'cds/'

sequence = 'ENSG00000100304.fa'

aln = load_unaligned_seqs(filename = folder_in + sequence, format="fasta", moltype='dna')
aln
# Out:
# /home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/cogent3/util/warning.py:134: DeprecationWarning: argument format which will be removed in version 2025.9, use format_name instead
# reason='no longer has an effect'
#   deprecated(
# 3x dna seqcollection: (gorilla_gorilla-ENSGGOG00000010316[GGACTTGAAT...], ..., pan_troglodytes-ENSPTRG00000014470[ATGGAGGCCG...])

# %%
humanaln = aln.seqs["homo_sapiens-ENSG00000100304"]
humanaln
# Out:
# DnaSequence(ATGGAGG... 1,935)

# %%
ensemblseq  = make_seq("...", "ensemblseq", moltype="dna")
ensemblseq
# Out:
# DnaSequence(ATGGAGG... 1,935)

# %%
alnhomo = make_unaligned_seqs({humanaln, ensemblseq}, moltype="dna")
alnhomo
#aln, tree = tree_align("HKY85", alnhomo)
# Out:
# 1x dna seqcollection: (homo_sapiens-ENSG00000100304[ATGGAGGCCG...])

# %%
aln.variable_positions()
# Out:
# (310,)

# %%
aln[309:320]
# Out:
# 2 x 11 dna alignment: homo_sapiens-ENSG00000100304[ACCAGGGAGA...], ncbiseq[A-CAGGGAGA...]

# %%
gorillaaln = aln.seqs["gorilla_gorilla-ENSGGOG00000010316"]
gorillaaln
# Out:
# DnaSequence(GGACTTG... 1,923)

# %%
ensemblseq  = make_seq("...", "ensemblseq", moltype="dna")
ensemblseq
# Out:
# DnaSequence(GGACTTG... 1,923)

# %%
alngorilla = make_unaligned_seqs({gorillaaln, ensemblseq}, moltype="dna")
alngorilla
# Out:
# 1x dna seqcollection: (gorilla_gorilla-ENSGGOG00000010316[GGACTTGAAT...])
