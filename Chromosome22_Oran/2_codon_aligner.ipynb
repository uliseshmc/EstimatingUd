# %%
import cogent3
from cogent3 import get_app
import libs
import paths

# %%
#set folders to read and export data
folder_in = paths.DATA_HUMCHIMPORANG115 + 'cds/chrm22/'
folder_out = paths.DATA_HUMCHIMPORANG115 + 'cds/chrm22/codon_aligned'

in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')
out_dstore = cogent3.open_data_store(folder_out, suffix='fa', mode="w")

in_dstore.describe
# Out:
# Directory datastore
# =======================
# record type      number
# -----------------------
# completed           399
# not_completed         0
# logs                  1
# -----------------------
#
# 3 rows x 2 columns

# %%
#perform a codon alignment and remove stop codons
loader = get_app("load_unaligned", moltype="dna")
rename = libs.renamer_cds_unaligned()
#why do I trim stop codons? Does this mean that the stop codon is ereased and the rest of the sequence is still analyzed
trim_stops = get_app("trim_stop_codons")
codon_align = get_app("progressive_align", "codon", guide_tree="(Human:0.06,Chimpanzee:0.06,Orangutan:0.14)")
writer = get_app("write_seqs", data_store = out_dstore)
app = loader + rename + trim_stops + codon_align + writer

#underscore is to specify a variable we are not gonna use later
#By using this renamer function I throw away sequences with paralogs
_ = list(app.apply_to(in_dstore[:], parallel = False))
print(out_dstore.describe)
out_dstore.summary_not_completed
# Out:
# Directory datastore
# =======================
# record type      number
# -----------------------
# completed           338
# not_completed        61
# logs                  1
# -----------------------
# not completed records
# =====================================================================================================================================
# type     origin                   message                                          num    source
# -------------------------------------------------------------------------------------------------------------------------------------
# ERROR    renamer_cds_unaligned    "ValueError: non-uniq...ction: {'Orangutan'}"     58    ENSG00000100347.fa, ENSG00000167037.fa, ...
# ERROR    progressive_align        "'TGA' at 'Human':199...:141 not in alphabet"      3    ENSG00000073169.fa, ENSG00000184470.fa, ...
# -------------------------------------------------------------------------------------------------------------------------------------
#
# 2 rows x 5 columns
