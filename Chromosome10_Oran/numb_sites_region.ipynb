# %%
import cogent3
from cogent3 import get_app
from cogent3.maths.matrix_exponential_integration import expected_number_subs
import matplotlib.pyplot as plt
import paths
import libs
import pandas as pd
import numpy as np

# %% [markdown]
# ## Intergenic Ancestral Repeats (IGAR)

# %%
folder_in = paths.DATA_APES114 + 'intergenicAR/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

#loading and cocatanating sequences
#rename_noncds eliminates files that do not contain Gorilla, Human and Chimp sequences or that has duplicates.
loader = get_app("load_aligned", moltype="dna")
omit_degs_noncds = get_app("omit_degenerates", moltype="dna")
rename_noncds = libs.renamer_noncds_aligned()
seq_length = libs.human_seq_length()

noncds_app = loader + omit_degs_noncds + rename_noncds + seq_length

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_IGAR = sum(values)
total_length_IGAR
# Out:
#    0%|          |00:00<?
# 2324114

# %% [markdown]
# ## CDS

# %%
folder_in = paths.DATA_APES114 + 'cds/codon_aligned'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

loader_cds = get_app("load_aligned", moltype="dna")   
omit_degs_cds = get_app("omit_degenerates", moltype="dna", motif_length=3)
seq_length_cds = libs.human_seq_length()

cds_process = loader_cds + omit_degs_cds + seq_length_cds

seq_lengths = [r for r in cds_process.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_cds = sum(values)
total_length_cds
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 543237

# %% [markdown]
# ## Introns

# %%
folder_in = paths.DATA_APES114 + 'introns/noUTRs/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_introns = sum(values)
total_length_introns
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 6684962

# %% [markdown]
# ## 5' UTR

# %%
folder_in = paths.DATA_APES114 + 'introns/5UTR/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_5UTR = sum(values)
total_length_5UTR
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 106413

# %% [markdown]
# ## 3' UTR

# %%
folder_in = paths.DATA_APES114 + 'introns/3UTR/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_3UTR = sum(values)
total_length_3UTR
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 100622

# %% [markdown]
# ## Introns Ancestral Repeats (IntronAR)

# %%
folder_in = paths.DATA_APES114 + 'intronsAR/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_intronAR = sum(values)
total_length_intronAR
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 5463116

# %% [markdown]
# ## Intergenic distal (5kb distal from transcript)

# %%
folder_in = paths.DATA_APES114 + 'distal_IG/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_distalIG = sum(values)
total_length_distalIG
# Out:
#    0%|          |00:00<?
# 1079639

# %% [markdown]
# ## Intergenic proximal 5' (5kb proximal from transcript start)

# %%
folder_in = paths.DATA_APES114 + 'proximal5_IG/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_proximal5IG = sum(values)
total_length_proximal5IG
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 539644

# %% [markdown]
# ## Intergenic proximal 3' (5kb proximal from transcript end)

# %%
folder_in = paths.DATA_APES114 + 'proximal3_IG/'
in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')

seq_lengths = [r for r in noncds_app.as_completed(in_dstore[:], parallel=True) if r]

values = [x.obj for x in seq_lengths]
total_length_proximal3IG = sum(values)
total_length_proximal3IG
# Out:
#    0%|          |00:00<?
# Exception ignored in: <function tqdm.__del__ at 0x7f0578d76840>
# Traceback (most recent call last):
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/std.py", line 1148, in __del__
#     self.close()
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 282, in close
#     self.disp(bar_style='success', check_delay=False)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/tqdm/notebook.py", line 171, in display
#     rtext.value = right
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 716, in __set__
#     self.set(obj, value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 706, in set
#     obj._notify_trait(self.name, old_value, new_value)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/traitlets/traitlets.py", line 1513, in _notify_trait
#     self.notify_change(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 700, in notify_change
#     self.send_state(key=name)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 586, in send_state
#     self._send(msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipywidgets/widgets/widget.py", line 825, in _send
#     self.comm.send(data=msg, buffers=buffers)
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/comm/base_comm.py", line 144, in send
#     self.publish_msg(
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/comm/comm.py", line 42, in publish_msg
#     parent=self.kernel.get_parent(),
#   File "/home/u12/uliseshmc/.conda/envs/delme/lib/python3.13/site-packages/ipykernel/kernelbase.py", line 797, in get_parent
#     return self._shell_parent.get()
# LookupError: <ContextVar name='shell_parent' at 0x7f059e3244f0>
# 539839

# %%
Length_data = pd.DataFrame([
        ['cds', total_length_cds],
        ['introns', total_length_introns],
        ['3UTR', total_length_3UTR],
        ['5UTR', total_length_5UTR],
        ['intronsAR', total_length_intronAR],
        ['distalIG', total_length_distalIG],
        ['proximal5IG', total_length_proximal5IG],
        ['proximal3IG', total_length_proximal3IG],
        ['IGAR', total_length_IGAR],
    ],
    columns = ['Sequence type', 'Haploid sequence length'])

Length_data.plot(
    x='Sequence type',
    kind = 'bar',
    rot=45)
plt.ylabel('Haploid sequence length')
# Out:
# Text(0, 0.5, 'Haploid sequence length')

# %%
Length_data.to_csv("Output_data/number_sites_perregion.csv", index=False)
Length_data
# Out:
#   Sequence type  Haploid sequence length
# 0           cds                   543237
# 1       introns                  6684962
# 2          3UTR                   100622
# 3          5UTR                   106413
# 4     intronsAR                  5463116
# 5      distalIG                  1079639
# 6   proximal5IG                   539644
# 7   proximal3IG                   539839
# 8          IGAR                  2324114

# %%
Total_length = sum(Length_data["Haploid sequence length"])
print(Total_length)
print(Total_length/1000000)
# Out:
# 17381586
# 17.381586
