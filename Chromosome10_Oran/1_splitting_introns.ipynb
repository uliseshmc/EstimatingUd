# %%
import cogent3
from cogent3 import get_app
import libs
import paths

# %% [markdown]
# Sampling 3' UTR

# %%
folder_in = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/'
folder_out = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/3UTR'

in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')
out_dstore = cogent3.open_data_store(folder_out, suffix='fa', mode="w")

loader = get_app("load_aligned", moltype="dna")
rename = libs.renamer_noncds_aligned()
get_UTR3 = libs.sample_UTR3()
writer = get_app("write_seqs", data_store = out_dstore)
app_UTR3 = loader + rename + get_UTR3 + writer

#underscore is to specify a variable we are not gonna use later
#By using this renamer function I throw away sequences with paralogs
_ = list(app_UTR3.apply_to(in_dstore[:], parallel = False))
print(out_dstore.describe)
out_dstore.summary_not_completed
# Out:
# Directory datastore
# =======================
# record type      number
# -----------------------
# completed           763
# not_completed        84
# logs                  1
# -----------------------
# not completed records
# ==========================================================================================================================================
# type     origin                    message                                          num    source
# ------------------------------------------------------------------------------------------------------------------------------------------
# ERROR    renamer_noncds_aligned    'ValueError: The foll...> at 0x1505d57eb7e0>'     71    ENSG00000178440.fa, ENSG00000253626.fa, ...
# ERROR    sample_UTR3               "TypeError: unsupport...'NoneType' and 'int'"     13    ENSG00000019995-1.fa, ENSG00000198879-0.fa, ...
# ------------------------------------------------------------------------------------------------------------------------------------------
#
# 2 rows x 5 columns

# %% [markdown]
# Sampling 5' UTR

# %%
folder_in = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/'
folder_out = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/5UTR'

in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')
out_dstore = cogent3.open_data_store(folder_out, suffix='fa', mode="w")


loader = get_app("load_aligned", moltype="dna")
rename = libs.renamer_noncds_aligned()
get_UTR5 = libs.sample_UTR5()
writer = get_app("write_seqs", data_store = out_dstore)
app_UTR5 = loader + rename + get_UTR5 + writer

#underscore is to specify a variable we are not gonna use later
#By using this renamer function I throw away sequences with paralogs
_ = list(app_UTR5.apply_to(in_dstore[:], parallel = False))
print(out_dstore.describe)
out_dstore.summary_not_completed
# Out:
# Directory datastore
# =======================
# record type      number
# -----------------------
# completed           776
# not_completed        71
# logs                  1
# -----------------------
# not completed records
# ======================================================================================================================================
# type     origin                    message                                          num    source
# --------------------------------------------------------------------------------------------------------------------------------------
# ERROR    renamer_noncds_aligned    'ValueError: non-uniq...> at 0x15060f6dede0>'     71    ENSG00000178440.fa, ENSG00000253626.fa, ...
# --------------------------------------------------------------------------------------------------------------------------------------
#
# 1 rows x 5 columns

# %% [markdown]
# Removing UTRs from intron sequences

# %%
folder_in = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/'
folder_out = paths.DATA_HUMCHIMPORANG115 + 'introns/chrm10/noUTRs'

in_dstore = cogent3.open_data_store(folder_in, suffix='fa', mode='r')
out_dstore = cogent3.open_data_store(folder_out, suffix='fa', mode="w")

loader = get_app("load_aligned", moltype="dna")
rename = libs.renamer_noncds_aligned()
remove_UTR = libs.removeUTRs_fromintrons()
writer = get_app("write_seqs", data_store = out_dstore)
app_noUTR = loader + rename + remove_UTR + writer

#underscore is to specify a variable we are not gonna use later
#By using this renamer function I throw away sequences with paralogs
_ = list(app_noUTR.apply_to(in_dstore[:], parallel = False))
print(out_dstore.describe)
out_dstore.summary_not_completed
# Out:
# Directory datastore
# =======================
# record type      number
# -----------------------
# completed           776
# not_completed        71
# logs                  1
# -----------------------
# not completed records
# ======================================================================================================================================
# type     origin                    message                                          num    source
# --------------------------------------------------------------------------------------------------------------------------------------
# ERROR    renamer_noncds_aligned    'ValueError: The foll...> at 0x15060f4251c0>'     71    ENSG00000178440.fa, ENSG00000253626.fa, ...
# --------------------------------------------------------------------------------------------------------------------------------------
#
# 1 rows x 5 columns
