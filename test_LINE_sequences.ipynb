# %%
import cogent3
from cogent3 import load_aligned_seqs
from cogent3 import util

# %%
util.io.get_format_suffixes('ENSG00000289721.fa')
# Out:
# ('fa', None)

# %%
folder = '/xdisk/masel/uliseshmc/EstimatingUd/primates10_112/aligns_line/chromosome1/'
sequence = 'ENSG00000289721.fa'
aln = load_aligned_seqs(folder + sequence, moltype='dna', new_type=True)

# %%
aln.names
# Out:
# ['pan_paniscus:1:138152328-138155125:1',
#  'macaca_fascicularis:1:91452631-91455436:-1',
#  'macaca_mulatta:1:91958567-91961376:-1',
#  'gorilla_gorilla:1:138103787-138106582:1',
#  'chlorocebus_sabaeus:20:4940016-4942815:-1',
#  'pan_troglodytes:1:137137022-137139812:1',
#  'pongo_abelii:1:91604081-91608290:-1',
#  'nomascus_leucogenys:12:43421715-43424781:-1',
#  'microcebus_murinus:2:117446113-117447915:-1',
#  'homo_sapiens:1:158999970-159002751:1']

# %%
aln = aln.rename_seqs(lambda x: x.split(':')[0])
aln = aln.take_seqs("homo_sapiens")
aln.set_repr_policy(num_pos=100000)
aln
# Out:
# 1 x 5342 dna alignment: homo_sapiens[TCAACATGCA...]

# %%
minialn = aln[778:972]
minialn.set_repr_policy(num_pos=100000)
minialn
# Out:
# 1 x 194 dna alignment: homo_sapiens[????????--...]

# %%
minialn.name_map
# Out:
# mappingproxy({'homo_sapiens': 'homo_sapiens:1:158999970-159002751:1'})

# %%
print(158999970+778)
print(158999970+972)
# Out:
# 159000748
# 159000942
